# %%
# Pivot 2 : baseline model inference
# I'm gonna run a pretrained huggingface model on balanced data to extract predictions nd confidence scores

# %%
# !pip install -q ipywidgets

# %%
# !pip install transformers torch torchvision tqdm

import os
import pandas as pd
from tqdm import tqdm
from transformers import pipeline
import logging

# %%
# load lightweight image classification model (hugging Face (ResNet-50)) 
from transformers import pipeline

age_gender_analyzer = pipeline(
    task="image-classification",
    model="microsoft/resnet-50",
    feature_extractor="microsoft/resnet-50",
    device=-1  # CPU
)

print("hugging Face vision model loaded successfully (ResNet50).")
# Out:
# Device set to use cpu
# hugging Face vision model loaded successfully (ResNet50).
